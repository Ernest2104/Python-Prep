# %%
mi_lista = ['Rojo','Azul','Amarillo','Naranja','Violeta','Verde']

print(mi_lista)

print(type(mi_lista))

print(mi_lista[5])

print(mi_lista[1:3])

print(mi_lista[:4])

print(mi_lista[2:])

mi_lista.append('Negro')
print(mi_lista)

mi_lista.insert(2,'Blanco')
print(mi_lista)
# Out:
# ['Rojo', 'Azul', 'Amarillo', 'Naranja', 'Violeta', 'Verde']
# <class 'list'>
# Verde
# ['Azul', 'Amarillo']
# ['Rojo', 'Azul', 'Amarillo', 'Naranja']
# ['Amarillo', 'Naranja', 'Violeta', 'Verde']
# ['Rojo', 'Azul', 'Amarillo', 'Naranja', 'Violeta', 'Verde', 'Negro']
# ['Rojo', 'Azul', 'Blanco', 'Amarillo', 'Naranja', 'Violeta', 'Verde', 'Negro']

# %%
mi_diccionario = {  'Colores Primarios': ['Rojo','Azul','Amarillo'], 
                    'Colores secundarios': ['Naranja','Violeta','Verde'], 
                    'Clave3': 10,
                    'Clave4': False}

# %%
print(mi_diccionario['Colores secundarios'])
# Out:
# ['Naranja', 'Violeta', 'Verde']

# %%
mi_diccionario['Clave5']='Otro ejemplo'
print(mi_diccionario)
# Out:
# {'Colores Primarios': ['Rojo', 'Azul', 'Amarillo'], 'Colores secundarios': ['Naranja', 'Violeta', 'Verde'], 'Clave3': 10, 'Clave4': False, 'Clave5': 'Otro ejemplo'}

# %%
mi_diccionario['Clave3']=2
print(mi_diccionario)
# Out:
# {'Colores Primarios': ['Rojo', 'Azul', 'Amarillo'], 'Colores secundarios': ['Naranja', 'Violeta', 'Verde'], 'Clave3': 2, 'Clave4': False, 'Clave5': 'Otro ejemplo'}
